# %% [markdown]
# <a href="https://colab.research.google.com/github/naveedfatima/Classpractice/blob/master/naveed.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
s=pd.Series([1,4,7,9,np.nan,60,34])
s
# Out:
# 0     1.0
# 1     4.0
# 2     7.0
# 3     9.0
# 4     NaN
# 5    60.0
# 6    34.0
# dtype: float64

# %%
dates= pd.date_range("20160819" , periods=7)
dates
# Out:
# DatetimeIndex(['2016-08-19', '2016-08-20', '2016-08-21', '2016-08-22',
#                '2016-08-23', '2016-08-24', '2016-08-25'],
#               dtype='datetime64[ns]', freq='D')

# %%
df=pd.DataFrame(np.random.randn(7,6), index=dates, columns=["A","B","C","D","E","F"])
# we can use list function to label columns as well i.e column=List("ABCDEF") and without List column=("ABCDEF")

# %%
df
# Out:
#                    A         B         C         D         E         F
# 2016-08-19  0.513918  0.043832  0.402725 -1.328038  0.834253 -0.080790
# 2016-08-20 -1.190859  0.669619  0.819634 -0.311168 -0.028766 -0.974196
# 2016-08-21  1.014435 -0.405513 -0.629931  0.031808 -0.544996 -0.051607
# 2016-08-22 -0.126554  1.856513  0.618767  0.690634  0.618464 -0.207711
# 2016-08-23 -0.507842  1.503148  1.644210  0.198939 -1.380618 -1.243731
# 2016-08-24  0.281748  0.950867  0.906976  2.136182  0.072815  0.004384
# 2016-08-25 -0.074857  0.416953 -1.125276  0.986706 -0.228387  0.226144

# %%
df2=pd.DataFrame(
    {"A": 1.0,
     "B":pd.Timestamp("20160925"),
     "C":pd.Series("8", index=list(range(4))),
     "D":np.array([3]*4,),
     "E":pd.Categorical(["pass","fail","pass","fail"]),
     "F": "hello",
    }
)
df2
# Out:
#      A          B  C  D     E      F
# 0  1.0 2016-09-25  8  3  pass  hello
# 1  1.0 2016-09-25  8  3  fail  hello
# 2  1.0 2016-09-25  8  3  pass  hello
# 3  1.0 2016-09-25  8  3  fail  hello

# %%
df2.dtypes
# Out:
# A          float64
# B    datetime64[s]
# C           object
# D            int64
# E         category
# F           object
# dtype: object

# %%
df2.head(2)
# Out:
#      A          B  C  D     E      F
# 0  1.0 2016-09-25  8  3  pass  hello
# 1  1.0 2016-09-25  8  3  fail  hello

# %%
df2.tail(2)
# Out:
#      A          B  C  D     E      F
# 2  1.0 2016-09-25  8  3  pass  hello
# 3  1.0 2016-09-25  8  3  fail  hello

# %%
df2.index
# Out:
# Index([0, 1, 2, 3], dtype='int64')

# %%
df2.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'E', 'F'], dtype='object')

# %%
df2.to_numpy()
# Out:
# array([[1.0, Timestamp('2016-09-25 00:00:00'), '8', 3, 'pass', 'hello'],
#        [1.0, Timestamp('2016-09-25 00:00:00'), '8', 3, 'fail', 'hello'],
#        [1.0, Timestamp('2016-09-25 00:00:00'), '8', 3, 'pass', 'hello'],
#        [1.0, Timestamp('2016-09-25 00:00:00'), '8', 3, 'fail', 'hello']],
#       dtype=object)

# %%
df2.describe()
# Out:
#          A                    B    D
# count  4.0                    4  4.0
# mean   1.0  2016-09-25 00:00:00  3.0
# min    1.0  2016-09-25 00:00:00  3.0
# 25%    1.0  2016-09-25 00:00:00  3.0
# 50%    1.0  2016-09-25 00:00:00  3.0
# 75%    1.0  2016-09-25 00:00:00  3.0
# max    1.0  2016-09-25 00:00:00  3.0
# std    0.0                  NaN  0.0

# %%
df2.T
# Out:
#                      0                    1                    2  \
# A                  1.0                  1.0                  1.0
# B  2016-09-25 00:00:00  2016-09-25 00:00:00  2016-09-25 00:00:00
# C                    8                    8                    8
# D                    3                    3                    3
# E                 pass                 fail                 pass
# F                hello                hello                hello
#
#                      3
# A                  1.0
# B  2016-09-25 00:00:00
# C                    8
# D                    3
# E                 fail
# F                hello

# %%
df2.sort_index(axis=0, ascending=False)
# Out:
#      A          B  C  D     E      F
# 3  1.0 2016-09-25  8  3  fail  hello
# 2  1.0 2016-09-25  8  3  pass  hello
# 1  1.0 2016-09-25  8  3  fail  hello
# 0  1.0 2016-09-25  8  3  pass  hello

# %%
df.sort_values(by="B")
# Out:
#                    A         B         C         D         E         F
# 2016-08-21  1.014435 -0.405513 -0.629931  0.031808 -0.544996 -0.051607
# 2016-08-19  0.513918  0.043832  0.402725 -1.328038  0.834253 -0.080790
# 2016-08-25 -0.074857  0.416953 -1.125276  0.986706 -0.228387  0.226144
# 2016-08-20 -1.190859  0.669619  0.819634 -0.311168 -0.028766 -0.974196
# 2016-08-24  0.281748  0.950867  0.906976  2.136182  0.072815  0.004384
# 2016-08-23 -0.507842  1.503148  1.644210  0.198939 -1.380618 -1.243731
# 2016-08-22 -0.126554  1.856513  0.618767  0.690634  0.618464 -0.207711

# %%
value = df.at['2016-08-21', 'B']

# %%
print(value)
# Out:
# -0.4055126534209688

# %%
value = df.iat[1, 2]
print(value)
# Out:
# 0.8196336499930886

# %%
subset = df.loc['2016-08-21':'2016-08-22', ['A', 'C']]
print(subset)
# Out:
#                    A         C
# 2016-08-21  1.014435 -0.629931
# 2016-08-22 -0.126554  0.618767

# %%
value = df.iloc[1, 2]
print(value)
# Out:
# 0.8196336499930886

# %%
# Finding the middle term
middle_term = df.iloc[len(df) // 2]
print("middle term")
print(middle_term)
# Out:
# middle term
# A   -0.126554
# B    1.856513
# C    0.618767
# D    0.690634
# E    0.618464
# F   -0.207711
# Name: 2016-08-22 00:00:00, dtype: float64

# %%
df.iloc[3]
# Out:
# A   -0.126554
# B    1.856513
# C    0.618767
# D    0.690634
# E    0.618464
# F   -0.207711
# Name: 2016-08-22 00:00:00, dtype: float64

# %%
df.iloc[3:5, 0:2]
# Out:
#                    A         B
# 2016-08-22 -0.126554  1.856513
# 2016-08-23 -0.507842  1.503148

# %%
df.iloc[[1, 2, 4], [0, 2]]
# Out:
#                    A         C
# 2016-08-20 -1.190859  0.819634
# 2016-08-21  1.014435 -0.629931
# 2016-08-23 -0.507842  1.644210

# %%
df["A"]
# Out:
# 2016-08-19    0.513918
# 2016-08-20   -1.190859
# 2016-08-21    1.014435
# 2016-08-22   -0.126554
# 2016-08-23   -0.507842
# 2016-08-24    0.281748
# 2016-08-25   -0.074857
# Freq: D, Name: A, dtype: float64

# %%
df.A
# Out:
# 2016-08-19    0.513918
# 2016-08-20   -1.190859
# 2016-08-21    1.014435
# 2016-08-22   -0.126554
# 2016-08-23   -0.507842
# 2016-08-24    0.281748
# 2016-08-25   -0.074857
# Freq: D, Name: A, dtype: float64

# %%
df[0:3]
# Out:
#                    A         B         C         D         E         F
# 2016-08-19  0.513918  0.043832  0.402725 -1.328038  0.834253 -0.080790
# 2016-08-20 -1.190859  0.669619  0.819634 -0.311168 -0.028766 -0.974196
# 2016-08-21  1.014435 -0.405513 -0.629931  0.031808 -0.544996 -0.051607

# %%
df.iloc[3:4]
# Out:
#                    A         B         C         D         E         F
# 2016-08-22 -0.126554  1.856513  0.618767  0.690634  0.618464 -0.207711

# %%
df.loc[dates[3:5]]
# Out:
#                    A         B         C         D         E         F
# 2016-08-22 -0.126554  1.856513  0.618767  0.690634  0.618464 -0.207711
# 2016-08-23 -0.507842  1.503148  1.644210  0.198939 -1.380618 -1.243731

# %%
df.loc[:, ["A", "B"]]
# Out:
#                    A         B
# 2016-08-19  0.513918  0.043832
# 2016-08-20 -1.190859  0.669619
# 2016-08-21  1.014435 -0.405513
# 2016-08-22 -0.126554  1.856513
# 2016-08-23 -0.507842  1.503148
# 2016-08-24  0.281748  0.950867
# 2016-08-25 -0.074857  0.416953

# %%
df.loc[["2016-08-19","2016-08-20"],:]
# Out:
#                    A         B         C         D         E         F
# 2016-08-19  0.513918  0.043832  0.402725 -1.328038  0.834253 -0.080790
# 2016-08-20 -1.190859  0.669619  0.819634 -0.311168 -0.028766 -0.974196

# %%
df.iat[1, 1]
# Out:
# 0.6696192079985247

# %%
df.iloc[1,1]
# Out:
# 0.6696192079985247

# %%
df[df["A"] > 0]
# Out:
#                    A         B         C         D         E         F
# 2016-08-19  0.513918  0.043832  0.402725 -1.328038  0.834253 -0.080790
# 2016-08-21  1.014435 -0.405513 -0.629931  0.031808 -0.544996 -0.051607
# 2016-08-24  0.281748  0.950867  0.906976  2.136182  0.072815  0.004384

# %%
df[df['A']>1]
# Out:
#                    A         B         C         D         E         F
# 2016-08-21  1.014435 -0.405513 -0.629931  0.031808 -0.544996 -0.051607

# %%
df[df>1]
# Out:
#                    A         B        C         D   E   F
# 2016-08-19       NaN       NaN      NaN       NaN NaN NaN
# 2016-08-20       NaN       NaN      NaN       NaN NaN NaN
# 2016-08-21  1.014435       NaN      NaN       NaN NaN NaN
# 2016-08-22       NaN  1.856513      NaN       NaN NaN NaN
# 2016-08-23       NaN  1.503148  1.64421       NaN NaN NaN
# 2016-08-24       NaN       NaN      NaN  2.136182 NaN NaN
# 2016-08-25       NaN       NaN      NaN       NaN NaN NaN
